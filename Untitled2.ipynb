# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraelGM2C1/PortF-lio/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
estoque_p = {
    "COD1": {"produto": "RADIO", "quantidade": 10, "preco": 80.0,},
    "COD2":  {"produto": "mouse", "quantidade": 10, "preco": 8.0},
    "COD3":  {"produto": "memora ram", "quantidade": 10, "preco": 121.70},
    "COD4":  {"produto": "tela", "quantidade": 10, "preco": 600.0},
    "COD5":  {"produto": "teclado", "quantidade": 25, "preco": 50.0},
    "COD6":  {"produto": "monitor", "quantidade": 15, "preco": 450.0},
    "COD7":  {"produto": "webcam", "quantidade": 30, "preco": 75.0},
    "COD8":  {"produto": "microfone", "quantidade": 20, "preco": 110.0},
    "COD9":  {"produto": "caixa de som", "quantidade": 40, "preco": 90.0},
    "COD10": {"produto": "roteador", "quantidade": 12, "preco": 180.0},
    "COD11": {"produto": "impressora", "quantidade": 8, "preco": 320.0},
    "COD12": {"produto": "pendrive", "quantidade": 50, "preco": 25.0},
    "COD13": {"produto": "HD externo", "quantidade": 10, "preco": 280.0},
    "COD14": {"produto": "SSD", "quantidade": 7, "preco": 350.0},
    "COD15": {"produto": "fone de ouvido", "quantidade": 35, "preco": 60.0},
    "COD16": {"produto": "placa de video", "quantidade": 5, "preco": 1200.0},
    "COD17": {"produto": "fonte de alimentacao", "quantidade": 18, "preco": 150.0},
    "COD18": {"produto": "gabinete", "quantidade": 10, "preco": 200.0},
    "COD19": {"produto": "processador", "quantidade": 6, "preco": 800.0},
    "COD20": {"produto": "cooler", "quantidade": 22, "preco": 40.0}
}
